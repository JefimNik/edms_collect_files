# %%
# 🧾 Python Cheatsheet: Логические проверки, списки, генераторы

# ✅ Логические проверки
all(x > 0 for x in nums)                     # Все > 0
any("err" in s for s in sheet_names)        # Хоть один содержит "err"
all(name in xls.sheet_names for name in required)  # Все нужные листы есть
any(name in xls.sheet_names for name in targets)   # Хоть один нужный лист есть

# 🔄 Перебор и генераторы
for i, val in enumerate(data):              # Перебор с индексом
for a, b in zip(list1, list2):              # Объединение списков
map(str.upper, names)                       # Применение функции к списку
filter(str.isdigit, ['1', 'a'])             # Оставить только цифры
[x**2 for x in range(5)]                    # Списковое выражение

# 📊 Агрегации
sum(nums)                                   # Сумма
min(scores), max(scores)                    # Мин/макс
len(items)                                  # Длина
sorted(values)                              # Сортировка

# 🧪 Множества (set)
set(X).issubset(Y) or set(X) <= set(Y)      # Все из X есть в Y
set(a) & set(b)                             # Пересечение
set(a) - set(b)                             # Только в a, не в b

# 🔁 Excel: типовые проверки
if all(sheet in xls.sheet_names for sheet in required): ...
if any(sheet in xls.sheet_names for sheet in optional): ...
if not any(sheet in xls.sheet_names for sheet in required): ...
